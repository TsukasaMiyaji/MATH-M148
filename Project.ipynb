# %%
import pandas as pd

client_data = pd.read_csv('Data/export.csv')
print(client_data.shape)

client_data
# Out:
# (64911906, 6)
#           customer_id  account_id  ed_id                  event_name  \
# 0          -784961211  1773350293     12    application_web_approved
# 1          -784961211  1773350293     19        application_web_view
# 2          -784961211  1773350293     19        application_web_view
# 3          -784961211  1773350293     19        application_web_view
# 4          -784961211  1773350293     19        application_web_view
# ...               ...         ...    ...                         ...
# 64911901   -865005459  -983311387     29        account_activitation
# 64911902   -865005459  -983311387      5                   view_cart
# 64911903   -865005459  -983311387     24       campaignemail_clicked
# 64911904   -865005459  -983311387     27  account_downpaymentcleared
# 64911905   -865005459  -983311387     28               order_shipped
#
#                    event_timestamp  journey_steps_until_end
# 0         2023-03-22T08:45:22.000Z                        1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
client_data.isna().any()
# Out:
# customer_id                False
# account_id                 False
# ed_id                      False
# event_name                 False
# event_timestamp            False
# journey_steps_until_end    False
# dtype: bool

# %%
client_data.head(10)
# Out:
#    customer_id  account_id  ed_id                event_name  \
# 0   -784961211  1773350293     12  application_web_approved
# 1   -784961211  1773350293     19      application_web_view
# 2   -784961211  1773350293     19      application_web_view
# 3   -784961211  1773350293     19      application_web_view
# 4   -784961211  1773350293     19      application_web_view
# 5   -784961211  1773350293     19      application_web_view
# 6   -784961211  1773350293     19      application_web_view
# 7   -784961211  1773350293     19      application_web_view
# 8   -784961211  1773350293     19      application_web_view
# 9   -784961211  1773350293     19      application_web_view
#
#             event_timestamp  journey_steps_until_end
# 0  2023-03-22T08:45:22.000Z                        1
# 1  2023-03-22T13:32:10.000Z                        2
# 2  2023-03-22T13:32:10.000Z                        3
# 3  2023-03-22T13:32:10.000Z                        4
# ...

# %%
test_cd = client_data[:1000]
test_cd
# Out:
#      customer_id  account_id  ed_id                event_name  \
# 0     -784961211  1773350293     12  application_web_approved
# 1     -784961211  1773350293     19      application_web_view
# 2     -784961211  1773350293     19      application_web_view
# 3     -784961211  1773350293     19      application_web_view
# 4     -784961211  1773350293     19      application_web_view
# ..           ...         ...    ...                       ...
# 995    940754364 -2103448386      4           browse_products
# 996    940754364 -2103448386      4           browse_products
# 997    940754364 -2103448386      4           browse_products
# 998    940754364 -2103448386      4           browse_products
# 999    940754364 -2103448386      4           browse_products
#
#               event_timestamp  journey_steps_until_end
# 0    2023-03-22T08:45:22.000Z                        1
# 1    2023-03-22T13:32:10.000Z                        2
# ...

# %%
start_time = time.time()  # Capture start time

filtered_data = test_cd.groupby(['customer_id', 'account_id']).apply(lambda x: x.drop('journey_steps_until_end', axis=1).drop_duplicates()).reset_index(drop=True)

end_time = time.time()  # Capture end time
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 0.03195595741271973 seconds

# %%
start_time = time.time()  # Capture start time

filtered_data = test_cd.drop('journey_steps_until_end', axis=1).drop_duplicates().reset_index(drop=True)

end_time = time.time()  # Capture end time
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 0.005398988723754883 seconds

# %%
a = test_cd.loc[:, test_cd.columns != 'journey_steps_until_end'].transform(lambda k: tuple(k))
a
# Out:
#      customer_id  account_id  ed_id                event_name  \
# 0     -784961211  1773350293     12  application_web_approved
# 1     -784961211  1773350293     19      application_web_view
# 2     -784961211  1773350293     19      application_web_view
# 3     -784961211  1773350293     19      application_web_view
# 4     -784961211  1773350293     19      application_web_view
# ..           ...         ...    ...                       ...
# 995    940754364 -2103448386      4           browse_products
# 996    940754364 -2103448386      4           browse_products
# 997    940754364 -2103448386      4           browse_products
# 998    940754364 -2103448386      4           browse_products
# 999    940754364 -2103448386      4           browse_products
#
#               event_timestamp
# 0    2023-03-22T08:45:22.000Z
# 1    2023-03-22T13:32:10.000Z
# 2    2023-03-22T13:32:10.000Z
# 3    2023-03-22T13:32:10.000Z
# 4    2023-03-22T13:32:10.000Z
# ..                        ...
# ...

# %%
filtered_data = client_data.drop('journey_steps_until_end', axis=1).drop_duplicates()

# %%
filtered_data.head(10)
# Out:
#     customer_id  account_id  ed_id                event_name  \
# 0    -784961211  1773350293     12  application_web_approved
# 1    -784961211  1773350293     19      application_web_view
# 14   -784961211  1773350293      3    application_web_submit
# 15   -784961211  1773350293      2            campaign_click
# 16   -784961211  1773350293     19      application_web_view
# 21   -784961211  1773350293     19      application_web_view
# 24     15849251   383997507      4           browse_products
# 25     15849251   383997507      4           browse_products
# 26     15849251   383997507      4           browse_products
# 27     15849251   383997507      4           browse_products
#
#              event_timestamp
# 0   2023-03-22T08:45:22.000Z
# 1   2023-03-22T13:32:10.000Z
# 14  2023-03-22T13:32:10.000Z
# 15  2023-03-22T14:45:22.000Z
# 16  2023-07-27T14:57:56.000Z
# 21  2023-08-29T16:01:06.000Z
# 24  2021-11-04T14:11:15.000Z
# 25  2021-11-04T14:11:29.000Z
# ...

# %%
filtered_data['journey_steps_until_end'] = filtered_data.groupby(['customer_id', 'account_id']).cumcount() + 1

# %%
filtered_data.shape
# Out:
# (56853035, 6)
